# %% [markdown]
# # **ESTATÍSTICAS DA GOOGLEPLAYSTORE**

# %% [markdown]
# # **ETAPA 1 - Ambiente**

# %% [markdown]
# ### Conectando ao Pandas

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Conectando ao Matplotlib

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # **ETAPA 2 - Desenvolvimento**

# %% [markdown]
# ## Tratando inconsistências iniciais nos dados da Loja Google

# %% [markdown]
# ### Conectando o arquivo csv ao notebook

# %%
loja_google = pd.read_csv("../Desafio/googleplaystore.csv") # Lendo o arquivo CSV

# %%
loja_google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Retirando duplicatas

# %%
loja_google = loja_google.sort_values(by='App', ascending=True) # Ordena os valores da coluna App em ordem alfabética
loja_google
# Out:
#                                                    App       Category  Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL     4.5
# 324                         - Free Comics - Comic Apps         COMICS     3.5
# 4541                                                .R          TOOLS     4.5
# 4636                                            /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS     NaN
# 4362                                        💎 I'm rich      LIFESTYLE     3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL     4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS     4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT     4.7
#
# ...

# %%
loja_google = loja_google.drop_duplicates() # Remove as linhas duplicadas do dataset

# %%
loja_google.shape # Mostra a quantidade de linhas e colunas do dataset
# Out:
# (10358, 13)

# %% [markdown]
# ### Informações sobre o Dataset

# %%
loja_google.info(memory_usage='deep') # Mostra informações sobre o dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 8884 to 882
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 7.0 MB

# %%
loja_google[['App', 'Reviews', 'Category','Installs', 'Type','Content Rating', 'Genres']].describe() 
# Mostra informações sobre as colunas selecionadas
# Out:
#            App Reviews Category    Installs   Type Content Rating Genres
# count    10358   10358    10358       10358  10357          10357  10358
# unique    9660    6002       34          22      3              6    120
# top     ROBLOX       0   FAMILY  1,000,000+   Free       Everyone  Tools
# freq         9     593     1943        1488   9591           8382    842

# %%
loja_google.columns # Mostra o nome das colunas
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
loja_google["Category"].unique() # Mostra os valores únicos da coluna Category
# Out:
# array(['SPORTS', 'SOCIAL', 'COMICS', 'TOOLS', 'COMMUNICATION',
#        'NEWS_AND_MAGAZINES', 'HEALTH_AND_FITNESS', 'FAMILY',
#        'BOOKS_AND_REFERENCE', 'LIFESTYLE', 'BUSINESS', 'SHOPPING',
#        'MEDICAL', 'GAME', 'FINANCE', 'PERSONALIZATION', 'PHOTOGRAPHY',
#        'TRAVEL_AND_LOCAL', 'DATING', 'PRODUCTIVITY', 'ART_AND_DESIGN',
#        'FOOD_AND_DRINK', 'VIDEO_PLAYERS', 'HOUSE_AND_HOME',
#        'MAPS_AND_NAVIGATION', 'ENTERTAINMENT', 'EVENTS', 'EDUCATION',
#        'AUTO_AND_VEHICLES', 'WEATHER', 'BEAUTY', 'LIBRARIES_AND_DEMO',
#        'PARENTING', '1.9'], dtype=object)

# %% [markdown]
# ### Tratando a coluna "Category"

# %%
linha_original = loja_google.loc[loja_google["Category"] == '1.9']
linha_original # Mostra a linha do dataset a ser tratada
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# Resolvendo o problema da linha 10472

# %%
linha_alterada = loja_google.loc[10472].copy()
linha_alterada # Copia a linha a ser tratada
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
linha_alterada = pd.DataFrame([linha_alterada])
linha_alterada # Transforma a linha em um DataFrame
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price  Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone             NaN  February 11, 2018
#
#       Last Updated Current Ver  Android Ver
# 10472       1.0.19  4.0 and up          NaN

# %%
linha_tratada = pd.Index(linha_alterada.loc[10472]).insert (1, 'Não Informado')
linha_tratada # Insere o valor 'Não Informado' na posição 1 da cópia da linha 10472
# Out:
# Index(['Life Made WI-Fi Touchscreen Photo Frame',
#                                  'Não Informado',
#                                            '1.9',
#                                             19.0,
#                                           '3.0M',
#                                         '1,000+',
#                                           'Free',
#                                              '0',
#                                       'Everyone',
#                                              nan,
#                              'February 11, 2018',
#                                         '1.0.19',
#                                     '4.0 and up',
#                                              nan],
#       dtype='object', name=10472)

# %%
linha_tratada = pd.Series(linha_tratada)
linha_tratada # Transforma a linha em uma Series
# Out:
# 0     Life Made WI-Fi Touchscreen Photo Frame
# 1                               Não Informado
# 2                                         1.9
# 3                                        19.0
# 4                                        3.0M
# 5                                      1,000+
# 6                                        Free
# 7                                           0
# 8                                    Everyone
# 9                                         NaN
# 10                          February 11, 2018
# 11                                     1.0.19
# 12                                 4.0 and up
# 13                                        NaN
# Name: 10472, dtype: object

# %%
del linha_tratada[13]
linha_tratada # Deleta a coluna 13 da Series linha_tratada
# Out:
# 0     Life Made WI-Fi Touchscreen Photo Frame
# 1                               Não Informado
# 2                                         1.9
# 3                                        19.0
# 4                                        3.0M
# 5                                      1,000+
# 6                                        Free
# 7                                           0
# 8                                    Everyone
# 9                                         NaN
# 10                          February 11, 2018
# 11                                     1.0.19
# 12                                 4.0 and up
# Name: 10472, dtype: object

# %%
linha_tratada = pd.DataFrame([linha_tratada])
linha_tratada # Transforma a Series linha_tratada em um DataFrame
# Out:
#                                             0              1    2     3   \
# 10472  Life Made WI-Fi Touchscreen Photo Frame  Não Informado  1.9  19.0
#
#          4       5     6  7         8   9                  10      11  \
# 10472  3.0M  1,000+  Free  0  Everyone NaN  February 11, 2018  1.0.19
#
#                12
# 10472  4.0 and up

# %%
linha_tratada.columns = loja_google.columns
linha_tratada # Renomeia as colunas do DataFrame linha_tratada com os nomes das colunas do dataset
# Out:
#                                            App       Category Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame  Não Informado    1.9     19.0
#
#        Size Installs  Type Price Content Rating  Genres       Last Updated  \
# 10472  3.0M   1,000+  Free     0       Everyone     NaN  February 11, 2018
#
#       Current Ver Android Ver
# 10472      1.0.19  4.0 and up

# %%
linha_tratada.index = [10841]
linha_tratada # Renomeia o índice do DataFrame linha_tratada
# Out:
#                                            App       Category Rating  Reviews  \
# 10841  Life Made WI-Fi Touchscreen Photo Frame  Não Informado    1.9     19.0
#
#        Size Installs  Type Price Content Rating  Genres       Last Updated  \
# 10841  3.0M   1,000+  Free     0       Everyone     NaN  February 11, 2018
#
#       Current Ver Android Ver
# 10841      1.0.19  4.0 and up

# %%
loja_google = pd.concat([loja_google, linha_tratada])
loja_google # Concatena o dataset loja_google com o DataFrame linha_tratada
# Out:
#                                                     App       Category Rating  \
# 8884               "i DT" Fútbol. Todos Somos Técnicos.         SPORTS    NaN
# 8532                      +Download 4 Instagram Twitter         SOCIAL    4.5
# 324                          - Free Comics - Comic Apps         COMICS    3.5
# 4541                                                 .R          TOOLS    4.5
# 4636                                             /u/app  COMMUNICATION    4.7
# ...                                                 ...            ...    ...
# 4362                                         💎 I'm rich      LIFESTYLE    3.8
# 2575      💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL    4.6
# 7559   📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS    4.0
# 882    🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT    4.7
# 10841           Life Made WI-Fi Touchscreen Photo Frame  Não Informado    1.9
#
# ...

# %%
loja_google.drop(10472, inplace=True)
loja_google # Remove a linha 10472 do dataset loja_google
# Out:
#                                                     App       Category Rating  \
# 8884               "i DT" Fútbol. Todos Somos Técnicos.         SPORTS    NaN
# 8532                      +Download 4 Instagram Twitter         SOCIAL    4.5
# 324                          - Free Comics - Comic Apps         COMICS    3.5
# 4541                                                 .R          TOOLS    4.5
# 4636                                             /u/app  COMMUNICATION    4.7
# ...                                                 ...            ...    ...
# 4362                                         💎 I'm rich      LIFESTYLE    3.8
# 2575      💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL    4.6
# 7559   📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS    4.0
# 882    🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT    4.7
# 10841           Life Made WI-Fi Touchscreen Photo Frame  Não Informado    1.9
#
# ...

# %% [markdown]
# ## Transformando os tipos de dados de algumas colunas do Dataset

# %% [markdown]
# ### Passando a coluna Reviews para o tipo Inteiro

# %%
loja_google['Reviews'].nunique() # Mostra a quantidade de valores únicos da coluna Reviews
# Out:
# 6001

# %%
loja_google["Reviews"].describe() # Mostra informações sobre a coluna Reviews
# Out:
# count    1.035800e+04
# mean     4.058654e+05
# std      2.696651e+06
# min      0.000000e+00
# 25%      3.200000e+01
# 50%      1.678500e+03
# 75%      4.640425e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
loja_google['Reviews'].unique() # Mostra os valores únicos da coluna Reviews
# Out:
# array([78158306, 78128208, 69119316, ...,        2,        1,        0])

# %%
loja_google['Reviews'] = loja_google['Reviews'].astype(int) # Transforma a coluna Reviews em int
loja_google['Reviews']
# Out:
# 2544    78158306
# 3943    78128208
# 336     69119316
# 3904    69109672
# 2604    66577446
#           ...
# 5843           0
# 7123           0
# 6664           0
# 6291           0
# 5126           0
# Name: Reviews, Length: 10358, dtype: int64

# %% [markdown]
# ### Tranformando a coluna Size no tipo INT

# %%
loja_google['Size'].unique() # Mostra os valores únicos da coluna Size
# Out:
# array([ 27000000,  98000000,  76000000,  97000000,  74000000,  40000000,
#         52000000,  14000000,  15000000,  88000000,  24000000,  85000000,
#         94000000,  99000000,  63000000,  92000000,  17000000,  62000000,
#         71000000,  70000000,  34000000,  95000000,  67000000,  58000000,
#        100000000,  59000000,  53000000,  96000000,  16000000,  26000000,
#         41000000,  51000000,  32000000,  11000000,  55000000,  60000000,
#         79000000,  69000000,  42000000,  77000000,  57000000,  82000000,
#         75000000,  36000000,  33000000,  68000000,  22000000,  50000000,
#         89000000,  18000000,  25000000,  78000000,  46000000,  49000000,
#         37000000,  72000000,  39000000,  87000000,  61000000,  28000000,
#         29000000,  48000000,  21000000,  35000000,  54000000,  12000000,
#         56000000,  38000000,  91000000,  45000000,  66000000,  31000000,
#         47000000,  43000000,  13000000,  20000000,  80000000,  65000000,
# ...

# %%
loja_google['Size'].describe() # Mostra informações sobre a coluna Size
# Out:
# count    1.035800e+04
# mean     3.722817e+07
# std      2.353726e+07
# min      1.100000e+04
# 25%      2.100000e+07
# 50%      2.700000e+07
# 75%      5.000000e+07
# max      1.000000e+08
# Name: Size, dtype: float64

# %%
loja_google['Size'] = loja_google['Size'].astype(str)
loja_google['Size'] # Transforma a coluna Size em string
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size, Length: 10358, dtype: object

# %%
loja_google['Size Novo'] = loja_google['Size'].str.replace('.','')
loja_google['Size Novo'] # Remove o ponto da coluna Size
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size Novo, Length: 10358, dtype: object

# %%
loja_google['Size Novo'] = loja_google['Size Novo'].str.replace('M','000000')
loja_google['Size Novo'] # Substitui o M por 000000 na coluna Size Novo
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size Novo, Length: 10358, dtype: object

# %%
loja_google['Size Novo'] = loja_google['Size Novo'].str.replace('k','000')
loja_google['Size Novo'] # Substitui o k por 000 na coluna Size Novo
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size Novo, Length: 10358, dtype: object

# %%
loja_google['Size Novo'] = loja_google['Size Novo'].str.replace('Varies with device','-1')
loja_google['Size Novo'] # Substitui o 'Varies with device' por -1 na coluna Size Novo
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size Novo, Length: 10358, dtype: object

# %%
loja_google['Size Novo'] = loja_google['Size Novo'].astype(int)
loja_google['Size Novo'] # Transforma a coluna Size Novo em int
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size Novo, Length: 10358, dtype: int64

# %%
for value in loja_google['Size Novo']:
  if value < 0:
    loja_google['Size Novo'] = loja_google['Size Novo'].replace(value, loja_google['Size Novo'].median())
loja_google['Size Novo'] # Substitui os valores negativos da coluna Size Novo pela mediana
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size Novo, Length: 10358, dtype: int64

# %%
loja_google['Size'] = loja_google['Size Novo']
loja_google['Size'] # Substitui a coluna Size pela coluna Size Novo
# Out:
# 2544    27000000
# 3943    27000000
# 336     27000000
# 3904    27000000
# 2604    27000000
#           ...
# 5843    51000000
# 7123    50000000
# 6664    12000000
# 6291    29000000
# 5126    17000000
# Name: Size, Length: 10358, dtype: int64

# %% [markdown]
# ### Transformando Installs no tipo inteiro

# %%
loja_google['Installs'].unique()
# Mostra os valores únicos da coluna Installs
# Out:
# array([1000000000,  100000000,  500000000,   50000000,   10000000,
#           5000000,    1000000,     500000,     100000,      50000,
#             10000,       5000,       1000,        500,        100,
#                10,         50,          5,          1,          0])

# %%
loja_google['Installs'] = loja_google['Installs'].astype(str)
loja_google['Installs'] # Transforma a coluna Installs em string
# Out:
# 2544    1000000000
# 3943    1000000000
# 336     1000000000
# 3904    1000000000
# 2604    1000000000
#            ...
# 5843            10
# 7123            50
# 6664            50
# 6291            10
# 5126             1
# Name: Installs, Length: 10358, dtype: object

# %%
loja_google['Installs'] = loja_google['Installs'].str.replace('+', '')
loja_google['Installs'] # Remove o sinal de + da coluna Installs
# Out:
# 2544    1000000000
# 3943    1000000000
# 336     1000000000
# 3904    1000000000
# 2604    1000000000
#            ...
# 5843            10
# 7123            50
# 6664            50
# 6291            10
# 5126             1
# Name: Installs, Length: 10358, dtype: object

# %%
loja_google['Installs'] = loja_google['Installs'].str.replace(',', '')
loja_google['Installs'] # Remove a vírgula da coluna Installs
# Out:
# 2544    1000000000
# 3943    1000000000
# 336     1000000000
# 3904    1000000000
# 2604    1000000000
#            ...
# 5843            10
# 7123            50
# 6664            50
# 6291            10
# 5126             1
# Name: Installs, Length: 10358, dtype: object

# %%
loja_google['Installs'] = loja_google['Installs'].astype(int)
loja_google['Installs'] # Transforma a coluna Installs em int
# Out:
# 2544    1000000000
# 3943    1000000000
# 336     1000000000
# 3904    1000000000
# 2604    1000000000
#            ...
# 5843            10
# 7123            50
# 6664            50
# 6291            10
# 5126             1
# Name: Installs, Length: 10358, dtype: int64

# %%
loja_google = loja_google.drop(columns=['Size Novo'])
 # Remove a coluna Size Novo do dataset

# %%
loja_google
# Out:
#                            App        Category Rating   Reviews      Size  \
# 2544                  Facebook          SOCIAL    4.1  78158306  27000000
# 3943                  Facebook          SOCIAL    4.1  78128208  27000000
# 336         WhatsApp Messenger   COMMUNICATION    4.4  69119316  27000000
# 3904        WhatsApp Messenger   COMMUNICATION    4.4  69109672  27000000
# 2604                 Instagram          SOCIAL    4.5  66577446  27000000
# ...                        ...             ...    ...       ...       ...
# 5843  Mehmet Emin Ay İlahileri          FAMILY    NaN         0  51000000
# 7123          Minwa HA ( C.B )  HOUSE_AND_HOME    NaN         0  50000000
# 6664          Miller's Bar B-Q  FOOD_AND_DRINK    NaN         0  12000000
# 6291                   MinT BI    PRODUCTIVITY    NaN         0  29000000
# 5126  Michael's AG Sound Board          FAMILY    NaN         0  17000000
#
#         Installs  Type  Price Content Rating         Genres  \
# ...

# %% [markdown]
# ## Gráfico de barras do top 5 apps mais instalados

# %% [markdown]
# ### Tratando os dados da coluna Reviews

# %%
loja_google_ordenada = loja_google.sort_values(by= ['Installs', 'Reviews'], ascending=False)
loja_google_ordenada # Ordena o dataset loja_google pela coluna Installs e Reviews em ordem decrescente
# Out:
#                                                App            Category Rating  \
# 2544                                      Facebook              SOCIAL    4.1
# 3943                                      Facebook              SOCIAL    4.1
# 336                             WhatsApp Messenger       COMMUNICATION    4.4
# 3904                            WhatsApp Messenger       COMMUNICATION    4.4
# 2604                                     Instagram              SOCIAL    4.5
# ...                                            ...                 ...    ...
# 7434                                 Pekalongan CJ              SOCIAL    NaN
# 4465  Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION    NaN
# 8614                             Sweden Newspapers  NEWS_AND_MAGAZINES    NaN
# 8871                        Test Application DT 02      ART_AND_DESIGN    NaN
# 6692                                 cronometra-br        PRODUCTIVITY    NaN
#
# ...

# %%
loja_google_ordenada = loja_google_ordenada.drop_duplicates(subset='App', keep='first')
loja_google_ordenada # Remove as linhas duplicadas do dataframe loja_google_ordenada
# Out:
#                                                App            Category Rating  \
# 2544                                      Facebook              SOCIAL    4.1
# 336                             WhatsApp Messenger       COMMUNICATION    4.4
# 2604                                     Instagram              SOCIAL    4.5
# 382       Messenger – Text and Video Chat for Free       COMMUNICATION    4.0
# 1917                                Subway Surfers                GAME    4.5
# ...                                            ...                 ...    ...
# 7434                                 Pekalongan CJ              SOCIAL    NaN
# 4465  Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION    NaN
# 8614                             Sweden Newspapers  NEWS_AND_MAGAZINES    NaN
# 8871                        Test Application DT 02      ART_AND_DESIGN    NaN
# 6692                                 cronometra-br        PRODUCTIVITY    NaN
#
# ...

# %%
top_5_apps = loja_google_ordenada.head(5)
top_5_apps # Mostra as 5 primeiras linhas do dataframe loja_google_ordenada
# Out:
#                                            App       Category Rating  \
# 2544                                  Facebook         SOCIAL    4.1
# 336                         WhatsApp Messenger  COMMUNICATION    4.4
# 2604                                 Instagram         SOCIAL    4.5
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION    4.0
# 1917                            Subway Surfers           GAME    4.5
#
#        Reviews      Size    Installs  Type Price Content Rating  \
# 2544  78158306  27000000  1000000000  Free     0           Teen
# 336   69119316  27000000  1000000000  Free     0       Everyone
# 2604  66577446  27000000  1000000000  Free     0           Teen
# 382   56646578  27000000  1000000000  Free     0       Everyone
# 1917  27725352  76000000  1000000000  Free     0   Everyone 10+
#
#              Genres    Last Updated         Current Ver         Android Ver
# 2544         Social  August 3, 2018  Varies with device  Varies with device
# ...

# %% [markdown]
# ### Visualizando o gráfico TOP 5 APPs mais instalados

# %%
plt.figure(figsize=(20, 10)) # Define o tamanho da figura
plt.bar(top_5_apps['App'], top_5_apps['Installs'], color = 'darkblue') # Plota um gráfico de barras com os 5 apps mais instalados
plt.xlabel('Apps Instalados', fontsize=20, fontweight='bold') # Define o título do eixo x
plt.xticks(rotation=80, fontsize=15, fontweight='bold') # Define a rotação, tamanho e peso da fonte do eixo x
plt.ylabel('Qtd de Installs (em bilhões)', fontsize=20, fontweight='bold', color='blue') # Define o título do eixo y
plt.yticks(fontsize=15, fontweight='bold') # Define o tamanho e peso da fonte do eixo y
plt.title('Top 5 Apps mais instalados', fontsize=30, color='red', fontweight='bold') # Define o título do gráfico
plt.show() # Plota um gráfico de barras com os 5 apps mais instalados

# %% [markdown]
# ## Gráfico de setores das categorias de apps e suas frequências

# %% [markdown]
# ### Tratando os dados, agrupando e criando tabela de frequência absoluta e relativa

# %%
loja_google_categorias = loja_google.drop_duplicates(subset='App', keep='first')
loja_google_categorias # Remove as linhas duplicadas do dataframe loja_google
# Out:
#                                            App        Category Rating  \
# 2544                                  Facebook          SOCIAL    4.1
# 336                         WhatsApp Messenger   COMMUNICATION    4.4
# 2604                                 Instagram          SOCIAL    4.5
# 382   Messenger – Text and Video Chat for Free   COMMUNICATION    4.0
# 1879                            Clash of Clans            GAME    4.6
# ...                                        ...             ...    ...
# 5843                  Mehmet Emin Ay İlahileri          FAMILY    NaN
# 7123                          Minwa HA ( C.B )  HOUSE_AND_HOME    NaN
# 6664                          Miller's Bar B-Q  FOOD_AND_DRINK    NaN
# 6291                                   MinT BI    PRODUCTIVITY    NaN
# 5126                  Michael's AG Sound Board          FAMILY    NaN
#
#        Reviews      Size    Installs  Type  Price Content Rating  \
# ...

# %%
loja_google_categorias ['Category'].isna().sum() # Mostra a quantidade de valores nulos da coluna Category
# Out:
# np.int64(0)

# %%
loja_google_categorias ['App'].isna().sum() # Mostra a quantidade de valores nulos da coluna App
# Out:
# np.int64(0)

# %%
frequencia_categoria = loja_google_categorias.groupby('Category').agg({"App":"count"}).reset_index()
frequencia_categoria # Agrupa o dataframe loja_google_categorias pela coluna Category
# Out:
#                Category   App
# 0        ART_AND_DESIGN    61
# 1     AUTO_AND_VEHICLES    85
# 2                BEAUTY    53
# 3   BOOKS_AND_REFERENCE   222
# 4              BUSINESS   420
# 5                COMICS    56
# 6         COMMUNICATION   315
# 7                DATING   170
# 8             EDUCATION   106
# 9         ENTERTAINMENT    86
# 10               EVENTS    64
# 11               FAMILY  1876
# 12              FINANCE   345
# 13       FOOD_AND_DRINK   112
# 14                 GAME   946
# 15   HEALTH_AND_FITNESS   288
# 16       HOUSE_AND_HOME    73
# 17   LIBRARIES_AND_DEMO    84
# 18            LIFESTYLE   369
# 19  MAPS_AND_NAVIGATION   131
# 20              MEDICAL   395
# 21   NEWS_AND_MAGAZINES   254
# 22        Não Informado     1
# 23            PARENTING    60
# 24      PERSONALIZATION   376
# 25          PHOTOGRAPHY   281
# 26         PRODUCTIVITY   374
# 27             SHOPPING   202
# 28               SOCIAL   239
# 29               SPORTS   325
# ...

# %%
frequencia_categoria['App'].sum() # Mostra a quantidade total de Apps
# Out:
# np.int64(9660)

# %%
frequencia_categoria['Porcentagem'] = frequencia_categoria['App'] / frequencia_categoria['App'].sum()
frequencia_categoria['Porcentagem'] = frequencia_categoria['Porcentagem'].map("{:.2%}".format)
frequencia_categoria # Calcula a porcentagem de Apps por Categoria
# Out:
#                Category   App Porcentagem
# 0        ART_AND_DESIGN    61       0.63%
# 1     AUTO_AND_VEHICLES    85       0.88%
# 2                BEAUTY    53       0.55%
# 3   BOOKS_AND_REFERENCE   222       2.30%
# 4              BUSINESS   420       4.35%
# 5                COMICS    56       0.58%
# 6         COMMUNICATION   315       3.26%
# 7                DATING   170       1.76%
# 8             EDUCATION   106       1.10%
# 9         ENTERTAINMENT    86       0.89%
# 10               EVENTS    64       0.66%
# 11               FAMILY  1876      19.42%
# 12              FINANCE   345       3.57%
# 13       FOOD_AND_DRINK   112       1.16%
# 14                 GAME   946       9.79%
# 15   HEALTH_AND_FITNESS   288       2.98%
# 16       HOUSE_AND_HOME    73       0.76%
# 17   LIBRARIES_AND_DEMO    84       0.87%
# 18            LIFESTYLE   369       3.82%
# 19  MAPS_AND_NAVIGATION   131       1.36%
# 20              MEDICAL   395       4.09%
# ...

# %% [markdown]
# ### Gráfico de setores das categorias por frequência relativa

# %%
my_labels = frequencia_categoria['Category']
# Cria uma lista com os valores da coluna Category
frequencia_categoria.plot.pie(y='App', labels=my_labels, figsize=(35,35), fontsize=22, labeldistance=1, 
                              legend=False, rotatelabels=True, autopct='%1.1f%%', 
                              startangle=140) # Plota um gráfico de pizza com a porcentagem de Apps por Categoria
plt.title('Frequência de Apps por Categoria', fontsize=50, fontweight='bold') # Adiciona um título ao gráfico
plt.show() # Plota um gráfico de pizza com a porcentagem de Apps por Categoria

# %% [markdown]
# ## App mais caro da loja

# %% [markdown]
# ### Tratando dados da coluna Price

# %%
loja_google_ordenada['Price'].describe() # Mostra informações sobre a coluna Price
# Out:
# count     9660
# unique      92
# top          0
# freq      8906
# Name: Price, dtype: object

# %%
loja_google_ordenada['Price'].unique() # Mostra os valores únicos da coluna Price
# Out:
# array(['0', '$6.99', '$0.99', '$2.99', '$1.99', '$2.49', '$4.99', '$5.99',
#        '$3.99', '$4.49', '$9.99', '$1.49', '$3.95', '$7.99', '$3.49',
#        '$8.99', '$13.99', '$11.99', '$2.90', '$399.99', '$14.99',
#        '$24.99', '$9.00', '$19.99', '$29.99', '$4.77', '$12.99', '$17.99',
#        '$2.95', '$3.90', '$2.50', '$3.28', '$1.20', '$2.59', '$1.59',
#        '$18.99', '$299.99', '$1.97', '$400.00', '$16.99', '$389.99',
#        '$10.00', '$5.49', '$1.00', '$4.60', '$33.99', '$10.99', '$4.84',
#        '$37.99', '$1.61', '$8.49', '$79.99', '$4.29', '$1.70', '$1.50',
#        '$1.29', '$19.40', '$3.08', '$379.99', '$2.56', '$15.46', '$7.49',
#        '$74.99', '$2.00', '$15.99', '$4.59', '$14.00', '$6.49', '$3.88',
#        '$39.99', '$3.02', '$5.00', '$19.90', '$1.26', '$1.75', '$2.60',
#        '$1.76', '$4.85', '$1.04', '$89.99', '$4.80', '$46.99', '$3.04',
#        '$3.61', '$25.99', '$1.96', '$109.99', '$28.99', '$200.00',
# ...

# %%
loja_google['Price Novo'] = loja_google['Price'].astype(str)
loja_google['Price Novo'] # Transforma a coluna Price em string
# Out:
# 8884           0
# 8532           0
# 324            0
# 4541           0
# 4636           0
#           ...
# 4362     $399.99
# 2575           0
# 7559           0
# 882            0
# 10841          0
# Name: Price Novo, Length: 10358, dtype: object

# %%
loja_google['Price Novo'] = loja_google['Price Novo'].str.replace('$', '')
loja_google['Price Novo'] # Remove o $ da coluna Price Novo
# Out:
# 8884          0
# 8532          0
# 324           0
# 4541          0
# 4636          0
#           ...
# 4362     399.99
# 2575          0
# 7559          0
# 882           0
# 10841         0
# Name: Price Novo, Length: 10358, dtype: object

# %%
loja_google['Price Novo'] = loja_google['Price Novo'].astype(float)
loja_google['Price Novo'] # Transforma a coluna Price Novo em float
# Out:
# 8884       0.00
# 8532       0.00
# 324        0.00
# 4541       0.00
# 4636       0.00
#           ...
# 4362     399.99
# 2575       0.00
# 7559       0.00
# 882        0.00
# 10841      0.00
# Name: Price Novo, Length: 10358, dtype: float64

# %%
loja_google['Price'] = loja_google['Price Novo']
loja_google['Price'] # Substitui a coluna Price pela coluna Price Novo
# Out:
# 8884       0.00
# 8532       0.00
# 324        0.00
# 4541       0.00
# 4636       0.00
#           ...
# 4362     399.99
# 2575       0.00
# 7559       0.00
# 882        0.00
# 10841      0.00
# Name: Price, Length: 10358, dtype: float64

# %%
loja_google = loja_google.drop(columns=['Price Novo']) # Remove a coluna Price Novo do dataset

# %%
loja_google_price = loja_google.sort_values(by='Price', ascending=False)
loja_google_price # Ordena o dataset loja_google pela coluna Price em ordem decrescente
# Out:
#                                                     App   Category Rating  \
# 4367                           I'm Rich - Trump Edition  LIFESTYLE    3.6
# 5359                                 I am rich(premium)    FINANCE    3.5
# 5351                                          I am rich  LIFESTYLE    3.8
# 5354                                     I am Rich Plus     FAMILY    4.0
# 4197                             most expensive app (H)     FAMILY    4.3
# ...                                                 ...        ...    ...
# 9200                                          বাংলাflix     FAMILY    4.2
# 1592             သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE    4.7
# 3960                       ► MultiCraft ― Free Miner! 👍       GAME    4.3
# 5569                           【Miku AR Camera】Mikuture     FAMILY    4.4
# 321   【Ranobbe complete free】 Novelba - Free app tha...     COMICS    NaN
#
#       Reviews      Size  Installs  Type   Price Content Rating         Genres  \
# ...

# %% [markdown]
# ### Mostrando o app mais caro

# %%
caro = loja_google_price["Price"].max() # Mostra o preço mais caro
condicao = loja_google_price["Price"] == caro # Mostra a condição do preço mais caro
loja_google_price[condicao][["App", "Price"]] # Mostra o app mais caro e o preço
# Out:
#                            App  Price
# 4367  I'm Rich - Trump Edition  400.0

# %% [markdown]
# ## Apps classificados como 'MATURE +17'

# %% [markdown]
# ### Tratando os dados da coluna 'Content Rating'

# %%
loja_google
# Out:
#                                                     App       Category Rating  \
# 8884               "i DT" Fútbol. Todos Somos Técnicos.         SPORTS    NaN
# 8532                      +Download 4 Instagram Twitter         SOCIAL    4.5
# 324                          - Free Comics - Comic Apps         COMICS    3.5
# 4541                                                 .R          TOOLS    4.5
# 4636                                             /u/app  COMMUNICATION    4.7
# ...                                                 ...            ...    ...
# 4362                                         💎 I'm rich      LIFESTYLE    3.8
# 2575      💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL    4.6
# 7559   📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS    4.0
# 882    🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT    4.7
# 10841           Life Made WI-Fi Touchscreen Photo Frame  Não Informado    1.9
#
# ...

# %%
loja_google['Content Rating'].unique() # Mostra os valores únicos da coluna Content Rating
# Out:
# array(['Everyone', 'Mature 17+', 'Everyone 10+', 'Teen', 'Unrated',
#        'Adults only 18+'], dtype=object)

# %%
loja_google_17 = loja_google.loc[loja_google["Content Rating"] == 'Mature 17+']
loja_google_17 # Mostra as linhas do dataset com a coluna Content Rating igual a Mature 17+
# Out:
#                                                     App       Category Rating  \
# 324                          - Free Comics - Comic Apps         COMICS    3.5
# 4636                                             /u/app  COMMUNICATION    4.7
# 8703    100000+ Messages - DP, Status, Jokes & GIF 2018      LIFESTYLE    3.7
# 7475                                        211:CK Lite           GAME    4.3
# 5835  25 Mins Ako ay may lobo Etc Pinoy Kid Song Off...         FAMILY    NaN
# ...                                                 ...            ...    ...
# 5431                                   virtual lover 3D         FAMILY    4.6
# 1593                                           w UN map      LIFESTYLE    4.2
# 6418                                      あなカレ【BL】無料ゲーム         FAMILY    4.7
# 313                 漫咖 Comics - Manga,Novel and Stories         COMICS    4.1
# 6334                            뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS    NaN
#
# ...

# %%
loja_google_17 = loja_google_17.sort_values(by='Reviews', ascending=False)
loja_google_17 # Ordena o dataframe loja_google_17 pela coluna Reviews em ordem decrescente
# Out:
#                                                      App            Category  \
# 3739                                             Twitter  NEWS_AND_MAGAZINES
# 4115                                             Twitter  NEWS_AND_MAGAZINES
# 1910    Sniper 3D Gun Shooter: Free Shooting Games - FPS                GAME
# 1723    Sniper 3D Gun Shooter: Free Shooting Games - FPS                GAME
# 1699    Sniper 3D Gun Shooter: Free Shooting Games - FPS                GAME
# ...                                                  ...                 ...
# 10701                                          F-O-Meter              FAMILY
# 621                                   Dating White Girls              DATING
# 7190                                           CD Supply            BUSINESS
# 627                                   CAM5678 Video Chat              DATING
# 5835   25 Mins Ako ay may lobo Etc Pinoy Kid Song Off...              FAMILY
#
# ...

# %%
loja_google_17 = loja_google_17.drop_duplicates(subset='App', keep='first')
loja_google_17 # Remove as linhas duplicadas do dataframe loja_google_17
# Out:
#                                                      App            Category  \
# 3739                                             Twitter  NEWS_AND_MAGAZINES
# 1910    Sniper 3D Gun Shooter: Free Shooting Games - FPS                GAME
# 6373                                                  VK              SOCIAL
# 4146                         Gangstar Vegas - mafia game                GAME
# 2592                        Tango - Live Video Broadcast              SOCIAL
# ...                                                  ...                 ...
# 10701                                          F-O-Meter              FAMILY
# 621                                   Dating White Girls              DATING
# 7190                                           CD Supply            BUSINESS
# 627                                   CAM5678 Video Chat              DATING
# 5835   25 Mins Ako ay may lobo Etc Pinoy Kid Song Off...              FAMILY
#
# ...

# %%
loja_google_17['Content Rating'].unique() # Confirma que apenas 'Mature 17+' aparece na coluna Content Rating
# Out:
# array(['Mature 17+'], dtype=object)

# %%
loja_google_17.shape # Mostra a quantidade de linhas e colunas dos apps para 'Mature 17+'
# Out:
# (393, 13)

# %% [markdown]
# ### Visualizando a tabela com os Apps 'Mature 17+'

# %%
loja_google_Mature17 = pd.DataFrame(loja_google_17['App'])
loja_google_Mature17 # Transforma a coluna App em DataFrame
# Out:
#                                                      App
# 3739                                             Twitter
# 1910    Sniper 3D Gun Shooter: Free Shooting Games - FPS
# 6373                                                  VK
# 4146                         Gangstar Vegas - mafia game
# 2592                        Tango - Live Video Broadcast
# ...                                                  ...
# 10701                                          F-O-Meter
# 621                                   Dating White Girls
# 7190                                           CD Supply
# 627                                   CAM5678 Video Chat
# 5835   25 Mins Ako ay may lobo Etc Pinoy Kid Song Off...
#
# [393 rows x 1 columns]

# %% [markdown]
# ## Top 10 apps por REVIEWS

# %% [markdown]
# ### Tratando a coluna Reviews

# %%
loja_google
#visualização de dados
# Out:
#                                                     App       Category Rating  \
# 8884               "i DT" Fútbol. Todos Somos Técnicos.         SPORTS    NaN
# 8532                      +Download 4 Instagram Twitter         SOCIAL    4.5
# 324                          - Free Comics - Comic Apps         COMICS    3.5
# 4541                                                 .R          TOOLS    4.5
# 4636                                             /u/app  COMMUNICATION    4.7
# ...                                                 ...            ...    ...
# 4362                                         💎 I'm rich      LIFESTYLE    3.8
# 2575      💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL    4.6
# 7559   📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS    4.0
# 882    🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT    4.7
# 10841           Life Made WI-Fi Touchscreen Photo Frame  Não Informado    1.9
#
# ...

# %%
loja_google = loja_google.sort_values(by='Reviews', ascending=False)
loja_google # Ordena o dataset loja_google pela coluna Reviews em ordem decrescente
# Out:
#                            App        Category Rating   Reviews      Size  \
# 2544                  Facebook          SOCIAL    4.1  78158306  27000000
# 3943                  Facebook          SOCIAL    4.1  78128208  27000000
# 336         WhatsApp Messenger   COMMUNICATION    4.4  69119316  27000000
# 3904        WhatsApp Messenger   COMMUNICATION    4.4  69109672  27000000
# 2604                 Instagram          SOCIAL    4.5  66577446  27000000
# ...                        ...             ...    ...       ...       ...
# 5843  Mehmet Emin Ay İlahileri          FAMILY    NaN         0  51000000
# 7123          Minwa HA ( C.B )  HOUSE_AND_HOME    NaN         0  50000000
# 6664          Miller's Bar B-Q  FOOD_AND_DRINK    NaN         0  12000000
# 6291                   MinT BI    PRODUCTIVITY    NaN         0  29000000
# 5126  Michael's AG Sound Board          FAMILY    NaN         0  17000000
#
#         Installs  Type  Price Content Rating         Genres  \
# ...

# %%
loja_google_reviews = loja_google.drop_duplicates(subset='App', keep='first')
loja_google_reviews # Remove as linhas duplicadas do dataframe loja_google_reviews
# Out:
#                                            App        Category Rating  \
# 2544                                  Facebook          SOCIAL    4.1
# 336                         WhatsApp Messenger   COMMUNICATION    4.4
# 2604                                 Instagram          SOCIAL    4.5
# 382   Messenger – Text and Video Chat for Free   COMMUNICATION    4.0
# 1879                            Clash of Clans            GAME    4.6
# ...                                        ...             ...    ...
# 5843                  Mehmet Emin Ay İlahileri          FAMILY    NaN
# 7123                          Minwa HA ( C.B )  HOUSE_AND_HOME    NaN
# 6664                          Miller's Bar B-Q  FOOD_AND_DRINK    NaN
# 6291                                   MinT BI    PRODUCTIVITY    NaN
# 5126                  Michael's AG Sound Board          FAMILY    NaN
#
#        Reviews      Size    Installs  Type  Price Content Rating  \
# ...

# %%
top_10_reviews = loja_google_reviews.head(10)
top_10_reviews # Mostra as 10 primeiras linhas do dataframe loja_google_reviews
# Out:
#                                                     App       Category Rating  \
# 2544                                           Facebook         SOCIAL    4.1
# 336                                  WhatsApp Messenger  COMMUNICATION    4.4
# 2604                                          Instagram         SOCIAL    4.5
# 382            Messenger – Text and Video Chat for Free  COMMUNICATION    4.0
# 1879                                     Clash of Clans           GAME    4.6
# 4005            Clean Master- Space Cleaner & Antivirus          TOOLS    4.7
# 1917                                     Subway Surfers           GAME    4.5
# 3665                                            YouTube  VIDEO_PLAYERS    4.3
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS    4.7
# 1878                                       Clash Royale           GAME    4.6
#
#        Reviews      Size    Installs  Type  Price Content Rating  \
# ...

# %%
top_10_reviews = pd.DataFrame(top_10_reviews)
top_10_reviews # Transforma o top 10 em DataFrame
# Out:
#                                                     App       Category Rating  \
# 2544                                           Facebook         SOCIAL    4.1
# 336                                  WhatsApp Messenger  COMMUNICATION    4.4
# 2604                                          Instagram         SOCIAL    4.5
# 382            Messenger – Text and Video Chat for Free  COMMUNICATION    4.0
# 1879                                     Clash of Clans           GAME    4.6
# 4005            Clean Master- Space Cleaner & Antivirus          TOOLS    4.7
# 1917                                     Subway Surfers           GAME    4.5
# 3665                                            YouTube  VIDEO_PLAYERS    4.3
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS    4.7
# 1878                                       Clash Royale           GAME    4.6
#
#        Reviews      Size    Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# ### Vizualizando a tabela com o top 10 Reviews

# %%
top_10 = top_10_reviews[['App', 'Reviews']] # Seleciona as colunas App e Reviews do top 10
top_10
# Out:
#                                                     App   Reviews
# 2544                                           Facebook  78158306
# 336                                  WhatsApp Messenger  69119316
# 2604                                          Instagram  66577446
# 382            Messenger – Text and Video Chat for Free  56646578
# 1879                                     Clash of Clans  44893888
# 4005            Clean Master- Space Cleaner & Antivirus  42916526
# 1917                                     Subway Surfers  27725352
# 3665                                            YouTube  25655305
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...  24900999
# 1878                                       Clash Royale  23136735

# %% [markdown]
# ## Top 30 apps por Price

# %% [markdown]
# ### Tratando os dados da coluna Price

# %%
loja_google_price
# Out:
#                                                     App   Category Rating  \
# 4367                           I'm Rich - Trump Edition  LIFESTYLE    3.6
# 5359                                 I am rich(premium)    FINANCE    3.5
# 5351                                          I am rich  LIFESTYLE    3.8
# 5354                                     I am Rich Plus     FAMILY    4.0
# 4197                             most expensive app (H)     FAMILY    4.3
# ...                                                 ...        ...    ...
# 9200                                          বাংলাflix     FAMILY    4.2
# 1592             သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE    4.7
# 3960                       ► MultiCraft ― Free Miner! 👍       GAME    4.3
# 5569                           【Miku AR Camera】Mikuture     FAMILY    4.4
# 321   【Ranobbe complete free】 Novelba - Free app tha...     COMICS    NaN
#
#       Reviews      Size  Installs  Type   Price Content Rating         Genres  \
# ...

# %%
loja_google_price = loja_google_price.sort_values(by='Reviews', ascending=False)
loja_google_price # Ordena o loja_google_price pela coluna Reviews em ordem decrescente
# Out:
#                             App          Category Rating   Reviews      Size  \
# 2544                   Facebook            SOCIAL    4.1  78158306  27000000
# 3943                   Facebook            SOCIAL    4.1  78128208  27000000
# 336          WhatsApp Messenger     COMMUNICATION    4.4  69119316  27000000
# 3904         WhatsApp Messenger     COMMUNICATION    4.4  69109672  27000000
# 2604                  Instagram            SOCIAL    4.5  66577446  27000000
# ...                         ...               ...    ...       ...       ...
# 6755   Corporate B.S. Generator          BUSINESS    NaN         0  69000000
# 4848                    Z PIVOT     COMMUNICATION    NaN         0  57000000
# 5176                Mitchell AH           MEDICAL    NaN         0  29000000
# 7176                 Kiosque CD  TRAVEL_AND_LOCAL    NaN         0  22000000
# 7163  Creative CD Letter Holder         LIFESTYLE    NaN         0  13000000
#
# ...

# %%
loja_google_price = loja_google_price.drop_duplicates(subset='App', keep='first')
loja_google_price # Remove as linhas duplicadas do dataframe loja_google_price
# Out:
#                                            App          Category Rating  \
# 2544                                  Facebook            SOCIAL    4.1
# 336                         WhatsApp Messenger     COMMUNICATION    4.4
# 2604                                 Instagram            SOCIAL    4.5
# 382   Messenger – Text and Video Chat for Free     COMMUNICATION    4.0
# 1879                            Clash of Clans              GAME    4.6
# ...                                        ...               ...    ...
# 6755                  Corporate B.S. Generator          BUSINESS    NaN
# 4848                                   Z PIVOT     COMMUNICATION    NaN
# 5176                               Mitchell AH           MEDICAL    NaN
# 7176                                Kiosque CD  TRAVEL_AND_LOCAL    NaN
# 7163                 Creative CD Letter Holder         LIFESTYLE    NaN
#
#        Reviews      Size    Installs  Type  Price Content Rating  \
# ...

# %%
loja_google_price = loja_google_price.sort_values(by='Price', ascending=False)
loja_google_price # Ordena o dataframe loja_google_price pela coluna Price em ordem decrescente
# Out:
#                                                     App   Category Rating  \
# 4367                           I'm Rich - Trump Edition  LIFESTYLE    3.6
# 9934                  I'm Rich/Eu sou Rico/أنا غني/我很有錢  LIFESTYLE    NaN
# 5362                                      I Am Rich Pro     FAMILY    4.4
# 5369                                          I am Rich    FINANCE    4.3
# 5364                     I am rich (Most expensive app)    FINANCE    4.1
# ...                                                 ...        ...    ...
# 8896  DU Battery Saver - Battery Charger & Battery Life      TOOLS    4.5
# 1871                                        8 Ball Pool       GAME    4.5
# 1908                                     My Talking Tom       GAME    4.5
# 4568    360 Security - Free Antivirus, Booster, Cleaner      TOOLS    4.6
# 5800                                          AX Window      TOOLS    NaN
#
#        Reviews      Size   Installs  Type   Price Content Rating  \
# ...

# %% [markdown]
# ### Separando as 30 primeiras linhas

# %%
top_30_price = loja_google_price.head(30)
top_30_price # Mostra as 20 primeiras linhas do dataframe loja_google_price
# Out:
#                                     App      Category Rating  Reviews  \
# 4367           I'm Rich - Trump Edition     LIFESTYLE    3.6      275
# 9934  I'm Rich/Eu sou Rico/أنا غني/我很有錢     LIFESTYLE    NaN        0
# 5362                      I Am Rich Pro        FAMILY    4.4      201
# 5369                          I am Rich       FINANCE    4.3      180
# 5364     I am rich (Most expensive app)       FINANCE    4.1      129
# 5358                         I am Rich!       FINANCE    3.8       93
# 4197             most expensive app (H)        FAMILY    4.3        6
# 5359                 I am rich(premium)       FINANCE    3.5      472
# 5373                 I AM RICH PRO PLUS       FINANCE    4.0       36
# 5354                     I am Rich Plus        FAMILY    4.0      856
# 4362                         💎 I'm rich     LIFESTYLE    3.8      718
# 5351                          I am rich     LIFESTYLE    3.8     3547
# ...

# %% [markdown]
# ### Visualização do top 30 apps mais caros

# %%
top_30 = top_30_price[['App', 'Price']] # Seleciona as colunas App e Price do top 30
top_30
# Out:
#                                     App   Price
# 4367           I'm Rich - Trump Edition  400.00
# 9934  I'm Rich/Eu sou Rico/أنا غني/我很有錢  399.99
# 5362                      I Am Rich Pro  399.99
# 5369                          I am Rich  399.99
# 5364     I am rich (Most expensive app)  399.99
# 5358                         I am Rich!  399.99
# 4197             most expensive app (H)  399.99
# 5359                 I am rich(premium)  399.99
# 5373                 I AM RICH PRO PLUS  399.99
# 5354                     I am Rich Plus  399.99
# 4362                         💎 I'm rich  399.99
# 5351                          I am rich  399.99
# 5356                  I Am Rich Premium  399.99
# 9917                        Eu Sou Rico  394.99
# 5366                          I Am Rich  389.99
# 5357                I am extremely Rich  379.99
# 5355                      I am rich VIP  299.99
# 9719                       EP Cook Book  200.00
# 6692                      cronometra-br  154.99
# ...

# %% [markdown]
# ## Média dos preços dos apps da Googleplaystore

# %% [markdown]
# ### Conferindo os dados nulos

# %%
loja_google_price['Price'].isna().sum() # Mostra a quantidade de valores nulos do dataframe loja_google_price
# Out:
# np.int64(0)

# %% [markdown]
# ### Calculando a média

# %%
media = loja_google_price['Price'].mean()
media # Mostra a média dos preços dos apps
# Out:
# np.float64(1.097116977225673)

# %%
media = pd.DataFrame(media)
media = media.rename(columns={0: 'Media'})
media # Transforma a média em DataFrame
# Out:
#       Media
# 0  1.097117

# %% [markdown]
# ## Gráfico de linhas dos apps por Price

# %% [markdown]
# ### Vizualização do gráfico de linhas

# %%
plt.plot(top_30['App'], top_30['Price']) # Plota um gráfico de linha com os 30 apps mais caros
plt.xlabel('APPs', fontsize=15, fontweight='bold') # Adiciona um título ao eixo x
plt.ylabel('PREÇO (em dolares)', fontsize=15, fontweight='bold') # Adiciona um título ao eixo y
plt.xticks(rotation=90, fontsize=10, fontweight='bold') # Ajusta o tamanho e o peso da fonte do eixo x
plt.yticks(fontsize=10, fontweight='bold') # Ajusta o tamanho e o peso da fonte do eixo y
plt.title('Top 30 Apps mais caros', fontsize=20, color='red', fontweight='bold') # Adiciona um título ao gráfico
plt.show() # Plota o gráfico

# %% [markdown]
# ## Gráfico de dispersão dos preços em relação à média

# %% [markdown]
# ### Agrupando os apps por preço

# %%
price_apps = loja_google_price.groupby('Price').agg({"App":"count"}).reset_index()
price_apps # Agrupa o dataframe loja_google_price pela coluna Price
# Out:
#      Price   App
# 0     0.00  8906
# 1     0.99   145
# 2     1.00     3
# 3     1.04     1
# 4     1.20     1
# ..     ...   ...
# 87  379.99     1
# 88  389.99     1
# 89  394.99     1
# 90  399.99    12
# 91  400.00     1
#
# [92 rows x 2 columns]

# %% [markdown]
# ### Vizualização do gráfico de dispersão

# %%
figure = plt.scatter(price_apps['Price'], price_apps['App']) # Plota um gráfico de dispersão
figure.set_color(['blue', 'green', 'yellow', 'orange', 'brown']) # Define a cor do gráfico
spines = ['bottom', 'top', 'left', 'right'] # Define as bordas do gráfico
plt.xlabel('Preço (em $)', fontsize=15, fontweight='bold') # Adiciona um rótulo no eixo x
plt.ylabel('Qtd de Apps', fontsize=15, fontweight='bold') # Adiciona um rótulo no eixo y
plt.xticks(fontsize=10, fontweight='bold') # Ajusta o tamanho da fonte do eixo x
plt.yticks(fontsize=10, fontweight='bold') # Ajusta o tamanho da fonte do eixo y
plt.meanline = plt.axvline(x=media['Media'].mean(), color='r', linestyle='--', label='Média')
# Adiciona uma linha vertical na média dos preços
plt.legend() # Adiciona uma legenda ao gráfico
plt.title( 'Preço x Qtd de APPs', fontsize=20, color='red', fontweight='bold') # Adiciona um título ao gráfico
plt.show() # Plota o gráfico
